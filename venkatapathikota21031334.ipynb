# %% [markdown]
# # Importing Python libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("API_19_DS2_en_csv_v2_4028487.csv", skiprows=3)

# %% [markdown]
# # Arranging dataset

# %%
data
# Out:
#       Country Name Country Code  \
# 0            Aruba          ABW
# 1            Aruba          ABW
# 2            Aruba          ABW
# 3            Aruba          ABW
# 4            Aruba          ABW
# ...            ...          ...
# 20211     Zimbabwe          ZWE
# 20212     Zimbabwe          ZWE
# 20213     Zimbabwe          ZWE
# 20214     Zimbabwe          ZWE
# 20215     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0               Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1                                       Urban population        SP.URB.TOTL
# 2                     Urban population growth (annual %)        SP.URB.GROW
# 3                                      Population, total        SP.POP.TOTL
# 4                           Population growth (annual %)        SP.POP.GROW
# ...                                                  ...                ...
# ...

# %%
data1= data.fillna(data.mean())
data1
# Out:
#       Country Name Country Code  \
# 0            Aruba          ABW
# 1            Aruba          ABW
# 2            Aruba          ABW
# 3            Aruba          ABW
# 4            Aruba          ABW
# ...            ...          ...
# 20211     Zimbabwe          ZWE
# 20212     Zimbabwe          ZWE
# 20213     Zimbabwe          ZWE
# 20214     Zimbabwe          ZWE
# 20215     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0               Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1                                       Urban population        SP.URB.TOTL
# 2                     Urban population growth (annual %)        SP.URB.GROW
# 3                                      Population, total        SP.POP.TOTL
# 4                           Population growth (annual %)        SP.POP.GROW
# ...                                                  ...                ...
# ...

# %% [markdown]
# # Detection of missing values

# %%
data1.isnull().sum()
# Out:
# Country Name          0
# Country Code          0
# Indicator Name        0
# Indicator Code        0
# 1960                  0
#                   ...
# 2018                  0
# 2019                  0
# 2020                  0
# 2021                  0
# Unnamed: 66       20216
# Length: 67, dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20216 entries, 0 to 20215
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    20216 non-null  object
#  1   Country Code    20216 non-null  object
#  2   Indicator Name  20216 non-null  object
#  3   Indicator Code  20216 non-null  object
#  4   1960            20216 non-null  float64
#  5   1961            20216 non-null  float64
#  6   1962            20216 non-null  float64
#  7   1963            20216 non-null  float64
#  8   1964            20216 non-null  float64
#  9   1965            20216 non-null  float64
#  10  1966            20216 non-null  float64
#  11  1967            20216 non-null  float64
#  12  1968            20216 non-null  float64
#  13  1969            20216 non-null  float64
#  14  1970            20216 non-null  float64
#  15  1971            20216 non-null  float64
#  16  1972            20216 non-null  float64
# ...

# %%
data1.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.021600e+04  2.021600e+04  2.021600e+04  2.021600e+04  2.021600e+04
# mean   2.404847e+07  1.664095e+07  1.671457e+07  1.851803e+07  1.908307e+07
# std    6.953313e+07  7.486629e+07  7.941852e+07  8.697295e+07  9.091133e+07
# min   -3.667000e+00 -3.667000e+00 -3.667000e+00 -3.703670e+02 -3.667000e+00
# 25%    2.404847e+07  1.664095e+07  1.671457e+07  1.851803e+07  1.908307e+07
# 50%    2.404847e+07  1.664095e+07  1.671457e+07  1.851803e+07  1.908307e+07
# 75%    2.404847e+07  1.664095e+07  1.671457e+07  1.851803e+07  1.908307e+07
# max    3.040000e+09  3.428000e+09  3.797000e+09  4.362000e+09  4.653000e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.021600e+04  2.021600e+04  2.021600e+04  2.021600e+04  2.021600e+04
# mean   1.981395e+07  2.223174e+07  2.221332e+07  2.472147e+07  2.608808e+07
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20216 entries, 0 to 20215
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    20216 non-null  object
#  1   Country Code    20216 non-null  object
#  2   Indicator Name  20216 non-null  object
#  3   Indicator Code  20216 non-null  object
#  4   1960            20216 non-null  int64
#  5   1961            20216 non-null  int64
#  6   1962            20216 non-null  int64
#  7   1963            20216 non-null  int64
#  8   1964            20216 non-null  int64
#  9   1965            20216 non-null  int64
#  10  1966            20216 non-null  int64
#  11  1967            20216 non-null  int64
#  12  1968            20216 non-null  int64
#  13  1969            20216 non-null  int64
#  14  1970            20216 non-null  int64
#  15  1971            20216 non-null  int64
#  16  1972            20216 non-null  int64
# ...

# %%
data1.count()
# Out:
# Country Name      20216
# Country Code      20216
# Indicator Name    20216
# Indicator Code    20216
# 1960              20216
#                   ...
# 2018              20216
# 2019              20216
# 2020              20216
# 2021              20216
# Unnamed: 66           0
# Length: 67, dtype: int64

# %%
data1 = data1.drop(["1960", "1961", "1962", "1963", "1964", "1965", "1966", "1967", "1968", "1969", "1970", "1971", "1972", "1973", "1974", "1975", "1976", "1977", "1978", "1979", "1980", "1981", "1982", "1983", "1984", "1985", "1986", "1987", "1988", "1989"], axis = 1)

# %%
data1=data1.fillna(0)

# %%
data1
# Out:
#       Country Name Country Code  \
# 0            Aruba          ABW
# 1            Aruba          ABW
# 2            Aruba          ABW
# 3            Aruba          ABW
# 4            Aruba          ABW
# ...            ...          ...
# 20211     Zimbabwe          ZWE
# 20212     Zimbabwe          ZWE
# 20213     Zimbabwe          ZWE
# 20214     Zimbabwe          ZWE
# 20215     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0               Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1                                       Urban population        SP.URB.TOTL
# 2                     Urban population growth (annual %)        SP.URB.GROW
# 3                                      Population, total        SP.POP.TOTL
# 4                           Population growth (annual %)        SP.POP.GROW
# ...                                                  ...                ...
# ...

# %%
data1.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1990              0
# 1991              0
# 1992              0
# 1993              0
# 1994              0
# 1995              0
# 1996              0
# 1997              0
# 1998              0
# 1999              0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# Unnamed: 66       0
# dtype: int64

# %%
a = data1['Country Name'].unique()
print(a)
# Out:
# ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czech Republic' 'Germany' 'Djibouti'
#  'Dominica' 'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
#  'Early-demographic dividend' 'East Asia & Pacific'
# ...

# %%
plt.figure(figsize=(16,9))
data1['2000'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='2000'>

# %%
fig = plt.figure(figsize = (16,9))
sns.lineplot(x = '2005', y = '1991', data = data1)
# Out:
# <AxesSubplot:xlabel='2005', ylabel='1991'>

# %% [markdown]
# ## 2 country representation

# %%
Aruba_data = data[data['Country Name'] == "Aruba"]
Aruba_data
# Out:
#    Country Name Country Code  \
# 0         Aruba          ABW
# 1         Aruba          ABW
# 2         Aruba          ABW
# 3         Aruba          ABW
# 4         Aruba          ABW
# ..          ...          ...
# 71        Aruba          ABW
# 72        Aruba          ABW
# 73        Aruba          ABW
# 74        Aruba          ABW
# 75        Aruba          ABW
#
#                                        Indicator Name     Indicator Code  \
# 0            Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1                                    Urban population        SP.URB.TOTL
# 2                  Urban population growth (annual %)        SP.URB.GROW
# 3                                   Population, total        SP.POP.TOTL
# 4                        Population growth (annual %)        SP.POP.GROW
# ..                                                ...                ...
# 71  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.ZS
# ...

# %%
UAE_data = data1[data1['Country Name'] == "United Arab Emirates"]
UAE_data
# Out:
#              Country Name Country Code  \
# 608  United Arab Emirates          ARE
# 609  United Arab Emirates          ARE
# 610  United Arab Emirates          ARE
# 611  United Arab Emirates          ARE
# 612  United Arab Emirates          ARE
# ..                    ...          ...
# 679  United Arab Emirates          ARE
# 680  United Arab Emirates          ARE
# 681  United Arab Emirates          ARE
# 682  United Arab Emirates          ARE
# 683  United Arab Emirates          ARE
#
#                                         Indicator Name     Indicator Code  \
# 608           Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 609                                   Urban population        SP.URB.TOTL
# 610                 Urban population growth (annual %)        SP.URB.GROW
# 611                                  Population, total        SP.POP.TOTL
# 612                       Population growth (annual %)        SP.POP.GROW
# ...

# %%
newdf = pd.concat([UAE_data, Aruba_data], axis=0)

# %%
newdf
# Out:
#              Country Name Country Code  \
# 608  United Arab Emirates          ARE
# 609  United Arab Emirates          ARE
# 610  United Arab Emirates          ARE
# 611  United Arab Emirates          ARE
# 612  United Arab Emirates          ARE
# ..                    ...          ...
# 71                  Aruba          ABW
# 72                  Aruba          ABW
# 73                  Aruba          ABW
# 74                  Aruba          ABW
# 75                  Aruba          ABW
#
#                                         Indicator Name     Indicator Code  \
# 608           Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 609                                   Urban population        SP.URB.TOTL
# 610                 Urban population growth (annual %)        SP.URB.GROW
# 611                                  Population, total        SP.POP.TOTL
# 612                       Population growth (annual %)        SP.POP.GROW
# ...

# %%
newdf.plot(x="Country Name", y=['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
        kind="bar", figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='Country Name'>

# %% [markdown]
# The ARuba country and UAE country data have been used to represent the land that are covered by the forest areas. Arabia country comprises of more urban population and thus forest area is less. The forest land are high in Aruba country.

# %%
from scipy.stats import kurtosis
import pylab as p
import numpy as np

# %%
data1.kurtosis(axis=None, skipna=None, level=None, numeric_only=None)
# Out:
# 1990           3406.636328
# 1991           3390.271765
# 1992           3370.214602
# 1993           3387.781368
# 1994           3385.036790
# 1995           3351.982162
# 1996           3361.552858
# 1997           3363.882725
# 1998           3355.486783
# 1999           3336.183434
# 2000           3317.371240
# 2001           3285.509950
# 2002           3296.902245
# 2003           3270.075539
# 2004           3256.773653
# 2005           3245.840453
# 2006           3217.685201
# 2007           3168.289241
# 2008           3120.642878
# 2009           3050.038103
# 2010           3022.013968
# 2011           2955.536648
# 2012           2882.795017
# 2013           2785.015488
# 2014           2753.304424
# 2015           2689.519453
# 2016           1574.494280
# 2017           1565.540265
# 2018           1556.827209
# 2019           1548.836836
# 2020           1540.766513
# 2021            241.621175
# Unnamed: 66       0.000000
# dtype: float64

# %%
data1
# Out:
#       Country Name Country Code  \
# 0            Aruba          ABW
# 1            Aruba          ABW
# 2            Aruba          ABW
# 3            Aruba          ABW
# 4            Aruba          ABW
# ...            ...          ...
# 20211     Zimbabwe          ZWE
# 20212     Zimbabwe          ZWE
# 20213     Zimbabwe          ZWE
# 20214     Zimbabwe          ZWE
# 20215     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0               Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1                                       Urban population        SP.URB.TOTL
# 2                     Urban population growth (annual %)        SP.URB.GROW
# 3                                      Population, total        SP.POP.TOTL
# 4                           Population growth (annual %)        SP.POP.GROW
# ...                                                  ...                ...
# ...

# %% [markdown]
# # Correlations

# %%
data1.corr()
# Out:
#                  1990      1991      1992      1993      1994      1995  \
# 1990         1.000000  0.993944  0.994074  0.994302  0.993120  0.987333
# 1991         0.993944  1.000000  0.999732  0.999723  0.999738  0.998327
# 1992         0.994074  0.999732  1.000000  0.999865  0.999723  0.998137
# 1993         0.994302  0.999723  0.999865  1.000000  0.999840  0.998110
# 1994         0.993120  0.999738  0.999723  0.999840  1.000000  0.998893
# 1995         0.987333  0.998327  0.998137  0.998110  0.998893  1.000000
# 1996         0.987514  0.998389  0.998185  0.998159  0.998942  0.999932
# 1997         0.982325  0.996042  0.995584  0.995737  0.996986  0.999209
# 1998         0.977951  0.993445  0.992635  0.993126  0.994694  0.997596
# 1999         0.975173  0.991827  0.990969  0.991395  0.993215  0.996730
# 2000         0.969705  0.987734  0.986557  0.987235  0.989401  0.993577
# 2001         0.960646  0.982266  0.981076  0.981838  0.984370  0.989854
# ...
